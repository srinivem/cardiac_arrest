# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivem/cardiac_arrest/blob/main/COVID_19_Prediction_CP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) IMPORTING LIBRARIES

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D,Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) CLONING DATASET

# %%
# CLONING THE DATASET FROM THE GITHUB REPOSITORY
# !git clone https://github.com/RishitToteja/Chext-X-ray-Images-Data-Set.git
# Out:
# Cloning into 'Chext-X-ray-Images-Data-Set'...
# remote: Enumerating objects: 2319, done.
# remote: Total 2319 (delta 0), reused 0 (delta 0), pack-reused 2319
# Receiving objects: 100% (2319/2319), 1.31 GiB | 12.21 MiB/s, done.
# Checking out files: 100% (2296/2296), done.

# %%
import os

main_dir = "/content/Chext-X-ray-Images-Data-Set/DataSet/Data"

# SETTING TRAIN AND TEST DIRECTORY
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

#SETING DIRECTORY FOR COVID AND NORMAL IMAGES DIRECTORY
train_covid_dir = os.path.join(train_dir, "COVID19")
train_normal_dir = os.path.join(train_dir, "NORMAL")

test_covid_dir = os.path.join(test_dir, "COVID19")
test_normal_dir = os.path.join(test_dir, "NORMAL")

# %%
# MAKING SEPERATE FILES : 
train_covid_names = os.listdir(train_covid_dir)
train_normal_names = os.listdir(train_normal_dir)

test_covid_names = os.listdir(test_covid_dir)
test_normal_names = os.listdir(test_normal_dir)

# %% [markdown]
# # 3) PERFORMING DATA VISUALIZATION

# %%
import matplotlib.image as mpimg

rows = 4
columns = 4

fig = plt.gcf()
fig.set_size_inches(12,12)

covid_img = [os.path.join(train_covid_dir, filename) for filename in train_covid_names[0:8]]
normal_img = [os.path.join(train_normal_dir, filename) for filename in train_normal_names[0:8]]

print(covid_img)
print(normal_img)

merged_img = covid_img + normal_img

for i, img_path in enumerate(merged_img):
  title = img_path.split("/", 6)[6]
  plot = plt.subplot(rows, columns, i+1)
  plot.axis("Off")
  img = mpimg.imread(img_path)
  plot.set_title(title, fontsize = 11)
  plt.imshow(img, cmap= "gray")

plt.show()
# Out:
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(445).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (177).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(416).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (259).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(136).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(432).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(470).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (3).jpeg']
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1067).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(417).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1358).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1494).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(867).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(272).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(422).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(552).jpg']

# %% [markdown]
# # 4) DATA PREPROCESSING AND AUGMENTATION

# %%
# CREATING TRAINING, TESTING AND VALIDATION BATCHES

dgen_train = ImageDataGenerator(rescale = 1./255,
                                validation_split = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)

dgen_validation = ImageDataGenerator(rescale = 1./255,
                                     )

dgen_test = ImageDataGenerator(rescale = 1./255,
                              )

train_generator = dgen_train.flow_from_directory(train_dir,
                                                 target_size = (150, 150), 
                                                 subset = 'training',
                                                 batch_size = 32,
                                                 class_mode = 'binary')
validation_generator = dgen_train.flow_from_directory(train_dir,
                                                      target_size = (150, 150), 
                                                      subset = "validation", 
                                                      batch_size = 32, 
                                                      class_mode = "binary")
test_generator = dgen_test.flow_from_directory(test_dir,
                                               target_size = (150, 150), 
                                               batch_size = 32, 
                                               class_mode = "binary")
# Out:
# Found 1449 images belonging to 2 classes.
# Found 362 images belonging to 2 classes.
# Found 484 images belonging to 2 classes.

# %%
print("Class Labels are: ", train_generator.class_indices)
print("Image shape is : ", train_generator.image_shape)
# Out:
# Class Labels are:  {'COVID19': 0, 'NORMAL': 1}
# Image shape is :  (150, 150, 3)

# %% [markdown]
# # 5) BUILDING CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

# 1) CONVOLUTIONAL LAYER - 1
model.add(Conv2D(32, (5,5), padding = "same", activation = "relu", input_shape = train_generator.image_shape))

# 2) POOLING LAYER - 1
model.add(MaxPooling2D(pool_size=(2,2)))

# 3) DROPOUT LAYER -2
model.add(Dropout(0.5))

# 4) CONVOLUTIONAL LAYER - 2
model.add(Conv2D(64, (5,5), padding = "same", activation = "relu"))

# 5) POOLING LAYER - 2
model.add(MaxPooling2D(pool_size=(2,2)))

# 6) DROPOUT LAYER - 2
model.add(Dropout(0.5))

# 7) FLATTENING LAYER TO 2D SHAPE
model.add(Flatten())

# 8) ADDING A DENSE LAYER
model.add(Dense(256, activation = 'relu'))

# 9 DROPOUT LAYER - 3
model.add(Dropout(0.5))

# 10) FINAL OUTPUT LAYER
model.add(Dense(1, activation = 'sigmoid'))

### PRINTING MODEL SUMMARY
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  dropout (Dropout)           (None, 75, 75, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 37, 37, 64)        0
#
#  flatten (Flatten)           (None, 87616)             0
#
#  dense (Dense)               (None, 256)               22429952
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 22,483,905
# Trainable params: 22,483,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 6) COMPILING AND TRAINING THE NEURAL NETWORK MODEL

# %%
# COMPILING THE MODEL

model.compile(Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# TRAINING THE MODEL
history = model.fit(train_generator, 
                    epochs = 35, 
                    validation_data = validation_generator)
# Out:
# Epoch 1/35
# 46/46 [==============================] - 66s 1s/step - loss: 1.8354 - accuracy: 0.6722 - val_loss: 0.4330 - val_accuracy: 0.7818
# Epoch 2/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.3200 - accuracy: 0.8551 - val_loss: 0.3091 - val_accuracy: 0.8757
# Epoch 3/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.2282 - accuracy: 0.9179 - val_loss: 0.1508 - val_accuracy: 0.9613
# Epoch 4/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1819 - accuracy: 0.9317 - val_loss: 0.1706 - val_accuracy: 0.9613
# Epoch 5/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1492 - accuracy: 0.9496 - val_loss: 0.1336 - val_accuracy: 0.9503
# Epoch 6/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1523 - accuracy: 0.9551 - val_loss: 0.1267 - val_accuracy: 0.9586
# Epoch 7/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1241 - accuracy: 0.9607 - val_loss: 0.1036 - val_accuracy: 0.9641
# Epoch 8/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1282 - accuracy: 0.9586 - val_loss: 0.0966 - val_accuracy: 0.9641
# Epoch 9/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1140 - accuracy: 0.9620 - val_loss: 0.0840 - val_accuracy: 0.9696
# Epoch 10/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1205 - accuracy: 0.9627 - val_loss: 0.0976 - val_accuracy: 0.9641
# Epoch 11/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1028 - accuracy: 0.9627 - val_loss: 0.0984 - val_accuracy: 0.9613
# Epoch 12/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.1130 - accuracy: 0.9648 - val_loss: 0.0968 - val_accuracy: 0.9696
# Epoch 13/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1284 - accuracy: 0.9607 - val_loss: 0.0951 - val_accuracy: 0.9558
# Epoch 14/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1218 - accuracy: 0.9579 - val_loss: 0.0630 - val_accuracy: 0.9724
# Epoch 15/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.1024 - accuracy: 0.9669 - val_loss: 0.0712 - val_accuracy: 0.9751
# Epoch 16/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1023 - accuracy: 0.9689 - val_loss: 0.0748 - val_accuracy: 0.9779
# Epoch 17/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0811 - accuracy: 0.9703 - val_loss: 0.0687 - val_accuracy: 0.9724
# Epoch 18/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0987 - accuracy: 0.9648 - val_loss: 0.0842 - val_accuracy: 0.9696
# Epoch 19/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.1177 - accuracy: 0.9620 - val_loss: 0.0583 - val_accuracy: 0.9834
# Epoch 20/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0877 - accuracy: 0.9710 - val_loss: 0.0817 - val_accuracy: 0.9751
# Epoch 21/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.0700 - accuracy: 0.9800 - val_loss: 0.0558 - val_accuracy: 0.9834
# Epoch 22/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.0777 - accuracy: 0.9745 - val_loss: 0.0490 - val_accuracy: 0.9862
# Epoch 23/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0637 - accuracy: 0.9772 - val_loss: 0.0638 - val_accuracy: 0.9807
# Epoch 24/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0732 - accuracy: 0.9772 - val_loss: 0.0605 - val_accuracy: 0.9751
# Epoch 25/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0741 - accuracy: 0.9745 - val_loss: 0.0787 - val_accuracy: 0.9779
# Epoch 26/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0744 - accuracy: 0.9765 - val_loss: 0.0341 - val_accuracy: 0.9917
# Epoch 27/35
# 46/46 [==============================] - 56s 1s/step - loss: 0.0820 - accuracy: 0.9758 - val_loss: 0.0499 - val_accuracy: 0.9862
# Epoch 28/35
# 46/46 [==============================] - 54s 1s/step - loss: 0.0588 - accuracy: 0.9827 - val_loss: 0.0492 - val_accuracy: 0.9779
# Epoch 29/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.0541 - accuracy: 0.9841 - val_loss: 0.0809 - val_accuracy: 0.9724
# Epoch 30/35
# 46/46 [==============================] - 56s 1s/step - loss: 0.0749 - accuracy: 0.9752 - val_loss: 0.0643 - val_accuracy: 0.9807
# Epoch 31/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.0697 - accuracy: 0.9772 - val_loss: 0.0656 - val_accuracy: 0.9779
# Epoch 32/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.0531 - accuracy: 0.9827 - val_loss: 0.0480 - val_accuracy: 0.9807
# Epoch 33/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.0550 - accuracy: 0.9807 - val_loss: 0.0538 - val_accuracy: 0.9890
# Epoch 34/35
# 46/46 [==============================] - 55s 1s/step - loss: 0.0516 - accuracy: 0.9841 - val_loss: 0.0824 - val_accuracy: 0.9696
# Epoch 35/35
# 46/46 [==============================] - 56s 1s/step - loss: 0.0548 - accuracy: 0.9827 - val_loss: 0.0539 - val_accuracy: 0.9807

# %% [markdown]
# # 7) PERFORMING EVALUATION

# %%
# KEYS OF HISTORY OBJECT
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION LOSS
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation losses")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION ACCURACY
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation accuracy")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# GETTING TEST ACCURACY AND LOSS

test_loss, test_acc = model.evaluate(test_generator)
print("Test Set Loss : ", test_loss)
print("Test Set Accuracy : ", test_acc)
# Out:
# 16/16 [==============================] - 12s 724ms/step - loss: 0.0879 - accuracy: 0.9669
# Test Set Loss :  0.08791493624448776
# Test Set Accuracy :  0.9669421315193176

# %% [markdown]
# # 9) PREDICTION ON NEW DATA (UPLOAD FILES)

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for filename in uploaded.keys():
  img_path = '/content/' + filename
  img = image.load_img(img_path, target_size = (150,150))
  images = image.img_to_array(img)
  images = np.expand_dims(images, axis = 0)
  prediction = model.predict(images)
  
  if prediction == 0:
    print("The report is COVID-19 Positive")
  else:
    print("The report is COVID-19 Negative")
# Out:
#      <input type="file" id="files-f74cf322-d362-43b5-be56-eaccf8b6486e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f74cf322-d362-43b5-be56-eaccf8b6486e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 000001-1.jpg to 000001-1.jpg
# The report is COVID-19 Positive

# %%
model.save("model.h5")
